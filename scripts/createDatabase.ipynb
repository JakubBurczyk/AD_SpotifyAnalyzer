# %%
from sqlalchemy import create_engine
from sqlalchemy.ext.declarative import declarative_base
import pandas as pd

from sqlalchemy import Column, Integer, String, Date, SmallInteger, Table, Float, MetaData, ForeignKey
from sqlalchemy.orm import relationship

# %%
db_string = "postgresql://admin:123@127.0.0.1:5432/spotify"
engine = create_engine(db_string)
Base = declarative_base()

# %%
class Artist(Base):
    __tablename__ = 'artist'
    artist_id = Column(Integer, primary_key=True)
    name = Column(String(50))

    def __repr__(self):
        return "<artist(id='{0}', name={1})>".format(self.artist_id, self.name)


class Song(Base):
    __tablename__ = 'song'
    song_id = Column(Integer, primary_key=True)
    title = Column(String(50))

    def __repr__(self):
        return "<song(id='{0}', name={1})>".format(self.song_id, self.title)

class SongArtist(Base):
    __tablename__ = 'song_artist'
    song_id = Column(Integer, primary_key=True)
    artist_id = Column(Integer, primary_key=True)

    def __repr__(self):
        return "<song id='{0}', artist id={1})>".format(self.song_id, self.artist_id)

class Trend(Base):
    __tablename__ = 'trend'
    trend_id = Column(Integer, primary_key=True)
    trend = Column(String(50))

    def __repr__(self):
        return "<trend(id='{0}', trend={1})>".format(self.trend_id, self.trend)

class Day(Base):
    __tablename__ = 'day'
    day_id = Column(Integer, primary_key=True)
    date = Column(Date)

    def __repr__(self):
        return "<date(id='{0}', date={1})>".format(self.day_id, self.date)

class Region(Base):
    __tablename__ = 'region'
    region_id = Column(Integer, primary_key=True)
    name = Column(String(50))

    def __repr__(self):
        return "<region(id='{0}', name={1})>".format(self.region_id, self.name)

class Category(Base):
    __tablename__ = 'category'
    category_id = Column(Integer, primary_key=True)
    name = Column(String(50))

    def __repr__(self):
        return "<category(id='{0}', name={1})>".format(self.category_id, self.name)

class Chart(Base):
    __tablename__ = 'chart'
    chart_id = Column(Integer, primary_key=True)
    position = Column(Integer)
    song_id = Column(Integer)
    day_id = Column(Integer)
    region_id = Column(Integer)
    category_id = Column(Integer)
    trend_id = Column(Integer)
    streams = Column(Integer)

    def __repr__(self):
        return "<chart(id='{0}', position={1}, song={2}, streams={3})>".format(self.chart_id, self.position, self.song_id, self.streams)

# %%
Base.metadata.create_all(engine)

# %%
data_ = pd.read_csv('..\data\charts.csv')
data_.head()
# Out:
#                          title  rank        date  \
# 0      Chantaje (feat. Maluma)     1  2017-01-01
# 1  Vente Pa' Ca (feat. Maluma)     2  2017-01-01
# 2   Reggaetón Lento (Bailemos)     3  2017-01-01
# 3                       Safari     4  2017-01-01
# 4                  Shaky Shaky     5  2017-01-01
#
#                                   artist  \
# 0                                Shakira
# 1                           Ricky Martin
# 2                                   CNCO
# 3  J Balvin, Pharrell Williams, BIA, Sky
# 4                           Daddy Yankee
#
#                                                  url     region   chart  \
# 0  https://open.spotify.com/track/6mICuAdrwEjh6Y6...  Argentina  top200
# 1  https://open.spotify.com/track/7DM4BPaS7uofFul...  Argentina  top200
# 2  https://open.spotify.com/track/3AEZUABDXNtecAO...  Argentina  top200
# 3  https://open.spotify.com/track/6rQSrBHf7HlZjtc...  Argentina  top200
# 4  https://open.spotify.com/track/58IL315gMSTD37D...  Argentina  top200
#
#            trend   streams
# 0  SAME_POSITION  253019.0
# 1        MOVE_UP  223988.0
# 2      MOVE_DOWN  210943.0
# 3  SAME_POSITION  173865.0
# 4        MOVE_UP  153956.0

# %%
data = data_.head(10000)

# %%
# Artist

df_artist = pd.DataFrame(data['artist'].unique(), columns=['name'])
df_artist = df_artist.assign(name=df_artist['name'].str.split(', ')).explode('name')
df_artist = pd.DataFrame(df_artist['name'].unique(), columns=['name'])
df_artist.reset_index(drop = True, inplace=True)
df_artist.insert(0, 'artist_id', range(1, 1 + len(df_artist)))

df_artist.head(10)
# Out:
#    artist_id               name
# 0          1            Shakira
# 1          2       Ricky Martin
# 2          3               CNCO
# 3          4           J Balvin
# 4          5  Pharrell Williams
# 5          6                BIA
# 6          7                Sky
# 7          8       Daddy Yankee
# 8          9    Sebastian Yatra
# 9         10             Rombai

# %%
# Song

df_song = pd.DataFrame(data['title'].unique(), columns=['title'])
df_song.insert(0, 'song_id', range(1, 1 + len(df_song)))

df_song.head(10)
# Out:
#    song_id                        title
# 0        1      Chantaje (feat. Maluma)
# 1        2  Vente Pa' Ca (feat. Maluma)
# 2        3   Reggaetón Lento (Bailemos)
# 3        4                       Safari
# 4        5                  Shaky Shaky
# 5        6                  Traicionera
# 6        7      Cuando Se Pone a Bailar
# 7        8    Otra vez (feat. J Balvin)
# 8        9                 La Bicicleta
# 9       10       Dile Que Tu Me Quieres

# %%
# Trend

df_trend = pd.DataFrame(data['trend'].unique(), columns=['trend'])
df_trend.insert(0, 'trend_id', range(1, 1 + len(df_trend)))

df_trend.head(10)
# Out:
#    trend_id          trend
# 0         1  SAME_POSITION
# 1         2        MOVE_UP
# 2         3      MOVE_DOWN
# 3         4      NEW_ENTRY

# %%
# Day

df_day = pd.DataFrame(data['date'].unique(), columns=['date'])
df_day.insert(0, 'day_id', range(1, 1 + len(df_day)))
#df_day['date'] = pd.to_datetime(df_day['date'], format="%Y/%m/%d")

df_day.head(10)
# Out:
#    day_id        date
# 0       1  2017-01-01
# 1       2  2017-01-02
# 2       3  2018-03-01
# 3       4  2018-03-02

# %%
# Region

df_region = pd.DataFrame(data['region'].unique(), columns=['name'])
df_region.insert(0, 'region_id', range(1, 1 + len(df_region)))

df_region.head(10)
# Out:
#    region_id       name
# 0          1  Argentina
# 1          2  Australia
# 2          3     Brazil
# 3          4    Austria
# 4          5    Belgium
# 5          6   Colombia
# 6          7    Bolivia
# 7          8    Denmark
# 8          9   Bulgaria
# 9         10     Canada

# %%
# Category

df_category = pd.DataFrame(data['chart'].unique(), columns=['name'])
df_category.insert(0, 'category_id', range(1, 1 + len(df_category)))

df_category.head(10)
# Out:
#    category_id    name
# 0            1  top200

# %%
# Song Artist
df_songArtist = pd.read_csv('..\data\df_songArtist.csv')
df_songArtist.rename(columns = {'title': 'song_id', 'artist': 'artist_id'}, inplace = True)
df_songArtist.reset_index(drop = True, inplace=True)

df_songArtist.head(10)
# Out:
#    song_id  artist_id
# 0        1          1
# 1        2          2
# 2        3          3
# 3        4          4
# 4        4          5
# 5        4          6
# 6        4          7
# 7        5          8
# 8        6          9
# 9        7         10

# %%
# Chart

df_chart = pd.read_csv('..\data\df_chart.csv')
df_chart = df_chart.rename(columns = {'title':'song_id', 'rank':'position', 'date':'day_id', 'region':'region_id', 'chart':'category_id', 'trend':'trend_id'})
df_chart.insert(0, 'chart_id', range(1, 1 + len(df_chart)))

df_chart['song_id'] = df_chart['song_id'].astype(pd.Int64Dtype())
df_chart['position'] = df_chart['position'].astype(pd.Int64Dtype())
df_chart['day_id'] = df_chart['day_id'].astype(pd.Int64Dtype())
df_chart['region_id'] = df_chart['region_id'].astype(pd.Int64Dtype())
df_chart['category_id'] = df_chart['category_id'].astype(pd.Int64Dtype())
df_chart['trend_id'] = df_chart['trend_id'].astype(pd.Int64Dtype())
df_chart['streams'] = df_chart['streams'].astype(pd.Int64Dtype())

df_chart.head(10)
# Out:
#    chart_id  song_id  position  day_id  region_id  category_id  trend_id  \
# 0         1        1         1       1          1            1         1
# 1         2        2         2       1          1            1         2
# 2         3        3         3       1          1            1         3
# 3         4        4         4       1          1            1         1
# 4         5        5         5       1          1            1         2
# 5         6        6         6       1          1            1         3
# 6         7        7         7       1          1            1         3
# 7         8        8         8       1          1            1         3
# 8         9        9         9       1          1            1         2
# 9        10       10        10       1          1            1         3
#
#    streams
# 0   253019
# 1   223988
# 2   210943
# 3   173865
# 4   153956
# 5   151140
# 6   148369
# 7   143004
# 8   126389
# 9   112012

# %%
df_artist.to_sql('artist', engine, if_exists='replace', index = False)
df_song.to_sql('song', engine, if_exists='replace', index = False)
df_songArtist.to_sql('song_artist', engine, if_exists='replace', index = False)
df_trend.to_sql('trend', engine, if_exists='replace', index = False)
df_day.to_sql('day', engine, if_exists='replace', index = False)
df_region.to_sql('region', engine, if_exists='replace', index = False)
df_category.to_sql('category', engine, if_exists='replace', index = False)
df_chart.to_sql('chart', engine, if_exists='replace', index = False)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# File e:\Programowanie\Anaconda\envs\marcinbereznicki\lib\site-packages\sqlalchemy\engine\base.py:1708, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1706         conn = self._revalidate_connection()
# -> 1708     context = constructor(
#    1709         dialect, self, conn, execution_options, *args, **kw
#    1710     )
#    1711 except (exc.PendingRollbackError, exc.ResourceClosedError):
#
# File e:\Programowanie\Anaconda\envs\marcinbereznicki\lib\site-packages\sqlalchemy\engine\default.py:995, in DefaultExecutionContext._init_compiled(cls, dialect, connection, dbapi_connection, execution_options, compiled, parameters, invoked_statement, extracted_parameters, cache_hit)
#     994 else:
# --> 995     self.compiled_parameters = [
#     996         compiled.construct_params(
#     997             m,
#     998             _group_number=grp,
#     999             extracted_parameters=extracted_parameters,
#    1000         )
#    1001         for grp, m in enumerate(parameters)
#    1002     ]
#    1004     self.executemany = len(parameters) > 1
#
# File e:\Programowanie\Anaconda\envs\marcinbereznicki\lib\site-packages\sqlalchemy\engine\default.py:996, in <listcomp>(.0)
#     994 else:
#     995     self.compiled_parameters = [
# --> 996         compiled.construct_params(
#     997             m,
#     998             _group_number=grp,
#     999             extracted_parameters=extracted_parameters,
#    1000         )
#    1001         for grp, m in enumerate(parameters)
#    1002     ]
#    1004     self.executemany = len(parameters) > 1
#
# File e:\Programowanie\Anaconda\envs\marcinbereznicki\lib\site-packages\sqlalchemy\sql\compiler.py:973, in SQLCompiler.construct_params(self, params, _group_number, _check, extracted_parameters)
#     972 if bindparam.key in params:
# --> 973     pd[escaped_name] = params[bindparam.key]
#     974 elif name in params:
#
# MemoryError:
#
# The above exception was the direct cause of the following exception:
#
# StatementError                            Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# e:\Programowanie\Microsoft VS Code Projects\Advanced Databases\AD_SpotifyAnalyzer\scripts\createDatabase.ipynb Cell 15' in <cell line: 8>()
#       <a href='vscode-notebook-cell:/e%3A/Programowanie/Microsoft%20VS%20Code%20Projects/Advanced%20Databases/AD_SpotifyAnalyzer/scripts/createDatabase.ipynb#ch0000017?line=6'>7</a> df_category.to_sql('category', engine, if_exists='replace', index = False)
# ----> <a href='vscode-notebook-cell:/e%3A/Programowanie/Microsoft%20VS%20Code%20Projects/Advanced%20Databases/AD_SpotifyAnalyzer/scripts/createDatabase.ipynb#ch0000017?line=7'>8</a> df_chart.to_sql('chart', engine, if_exists='replace', index = False)
#
# File e:\Programowanie\Anaconda\envs\marcinbereznicki\lib\site-packages\pandas\core\generic.py:2779, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2777 from pandas.io import sql
# -> 2779 sql.to_sql(
#    2780     self,
#    2781     name,
#    2782     con,
#    2783     schema=schema,
#    2784     if_exists=if_exists,
#    2785     index=index,
#    2786     index_label=index_label,
#    2787     chunksize=chunksize,
#    2788     dtype=dtype,
#    2789     method=method,
#    2790 )
#
# File e:\Programowanie\Anaconda\envs\marcinbereznicki\lib\site-packages\pandas\io\sql.py:601, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     597     raise NotImplementedError(
#     598         "'frame' argument should be either a Series or a DataFrame"
#     599     )
# --> 601 pandas_sql.to_sql(
#     602     frame,
#     603     name,
#     604     if_exists=if_exists,
#     605     index=index,
#     606     index_label=index_label,
#     607     schema=schema,
#     608     chunksize=chunksize,
#     609     dtype=dtype,
#     610     method=method,
#     611 )
#
# File e:\Programowanie\Anaconda\envs\marcinbereznicki\lib\site-packages\pandas\io\sql.py:1419, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1418     else:
# -> 1419         raise err
#    1421 if not name.isdigit() and not name.islower():
#    1422     # check for potentially case sensitivity issues (GH7815)
#    1423     # Only check when name is not a number and name is not lower case
#
# File e:\Programowanie\Anaconda\envs\marcinbereznicki\lib\site-packages\pandas\io\sql.py:1411, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1410 try:
# -> 1411     table.insert(chunksize, method=method)
#    1412 except exc.SQLAlchemyError as err:
#    1413     # GH34431
#
# File e:\Programowanie\Anaconda\envs\marcinbereznicki\lib\site-packages\pandas\io\sql.py:845, in SQLTable.insert(self, chunksize, method)
#     844 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 845 exec_insert(conn, keys, chunk_iter)
#
# File e:\Programowanie\Anaconda\envs\marcinbereznicki\lib\site-packages\pandas\io\sql.py:762, in SQLTable._execute_insert(self, conn, keys, data_iter)
#     761 data = [dict(zip(keys, row)) for row in data_iter]
# --> 762 conn.execute(self.table.insert(), data)
#
# File e:\Programowanie\Anaconda\envs\marcinbereznicki\lib\site-packages\sqlalchemy\engine\base.py:1295, in Connection.execute(self, statement, *multiparams, **params)
#    1294 else:
# -> 1295     return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#
# File e:\Programowanie\Anaconda\envs\marcinbereznicki\lib\site-packages\sqlalchemy\sql\elements.py:325, in ClauseElement._execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     324 if _force or self.supports_execution:
# --> 325     return connection._execute_clauseelement(
#     326         self, multiparams, params, execution_options
#     327     )
#     328 else:
#
# File e:\Programowanie\Anaconda\envs\marcinbereznicki\lib\site-packages\sqlalchemy\engine\base.py:1487, in Connection._execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1479 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1480     dialect=dialect,
#    1481     compiled_cache=compiled_cache,
#    (...)
#    1485     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1486 )
# -> 1487 ret = self._execute_context(
#    1488     dialect,
#    1489     dialect.execution_ctx_cls._init_compiled,
#    1490     compiled_sql,
#    1491     distilled_params,
#    1492     execution_options,
#    1493     compiled_sql,
#    1494     distilled_params,
#    1495     elem,
#    1496     extracted_params,
#    1497     cache_hit=cache_hit,
#    1498 )
#    1499 if has_events:
#
# File e:\Programowanie\Anaconda\envs\marcinbereznicki\lib\site-packages\sqlalchemy\engine\base.py:1714, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1713 except BaseException as e:
# -> 1714     self._handle_dbapi_exception(
#    1715         e, util.text_type(statement), parameters, None, None
#    1716     )
#    1718 if (
#    1719     self._transaction
#    1720     and not self._transaction.is_active
#    (...)
#    1724     )
#    1725 ):
#
# File e:\Programowanie\Anaconda\envs\marcinbereznicki\lib\site-packages\sqlalchemy\engine\base.py:2032, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2031 elif should_wrap:
# -> 2032     util.raise_(
#    2033         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2034     )
#    2035 else:
#
# File e:\Programowanie\Anaconda\envs\marcinbereznicki\lib\site-packages\sqlalchemy\util\compat.py:207, in raise_(***failed resolving arguments***)
#     206 try:
# --> 207     raise exception
#     208 finally:
#     209     # credit to
#     210     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     211     # as the __traceback__ object creates a cycle
#
# File e:\Programowanie\Anaconda\envs\marcinbereznicki\lib\site-packages\sqlalchemy\engine\base.py:1708, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1706         conn = self._revalidate_connection()
# -> 1708     context = constructor(
#    1709         dialect, self, conn, execution_options, *args, **kw
#    1710     )
#    1711 except (exc.PendingRollbackError, exc.ResourceClosedError):
#
# File e:\Programowanie\Anaconda\envs\marcinbereznicki\lib\site-packages\sqlalchemy\engine\default.py:995, in DefaultExecutionContext._init_compiled(cls, dialect, connection, dbapi_connection, execution_options, compiled, parameters, invoked_statement, extracted_parameters, cache_hit)
#     994 else:
# --> 995     self.compiled_parameters = [
#     996         compiled.construct_params(
#     997             m,
#     998             _group_number=grp,
#     999             extracted_parameters=extracted_parameters,
#    1000         )
#    1001         for grp, m in enumerate(parameters)
#    1002     ]
#    1004     self.executemany = len(parameters) > 1
#
# File e:\Programowanie\Anaconda\envs\marcinbereznicki\lib\site-packages\sqlalchemy\engine\default.py:996, in <listcomp>(.0)
#     994 else:
#     995     self.compiled_parameters = [
# --> 996         compiled.construct_params(
#     997             m,
#     998             _group_number=grp,
#     999             extracted_parameters=extracted_parameters,
#    1000         )
#    1001         for grp, m in enumerate(parameters)
#    1002     ]
#    1004     self.executemany = len(parameters) > 1
#
# File e:\Programowanie\Anaconda\envs\marcinbereznicki\lib\site-packages\sqlalchemy\sql\compiler.py:973, in SQLCompiler.construct_params(self, params, _group_number, _check, extracted_parameters)
#     972 if bindparam.key in params:
# --> 973     pd[escaped_name] = params[bindparam.key]
#     974 elif name in params:
#
# <class 'str'>: (<class 'MemoryError'>, MemoryError())
#
# During handling of the above exception, another exception occurred:
#
# MemoryError                               Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File e:\Programowanie\Anaconda\envs\marcinbereznicki\lib\site-packages\IPython\core\interactiveshell.py:2003, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2000     traceback.print_exc()
#    2001     return None
# -> 2003 self._showtraceback(etype, value, stb)
#    2004 if self.call_pdb:
#    2005     # drop into debugger
#    2006     self.debugger(force=True)
#
# File e:\Programowanie\Anaconda\envs\marcinbereznicki\lib\site-packages\ipykernel\zmqshell.py:542, in ZMQInteractiveShell._showtraceback(self, etype, evalue, stb)
#     536 sys.stdout.flush()
#     537 sys.stderr.flush()
#     539 exc_content = {
#     540     'traceback' : stb,
#     541     'ename' : str(etype.__name__),
# --> 542     'evalue' : str(evalue),
#     543 }
#     545 dh = self.displayhook
#     546 # Send exception info over pub socket for other clients than the caller
#     547 # to pick up
#
# File e:\Programowanie\Anaconda\envs\marcinbereznicki\lib\site-packages\sqlalchemy\exc.py:101, in SQLAlchemyError.__str__(self)
#     100 def __str__(self):
# --> 101     return self._sql_message(compat.py3k)
#
# File e:\Programowanie\Anaconda\envs\marcinbereznicki\lib\site-packages\sqlalchemy\exc.py:482, in StatementError._sql_message(self, as_unicode)
#     478         else:
#     479             params_repr = util._repr_params(
#     480                 self.params, 10, ismulti=self.ismulti
#     481             )
# --> 482             details.append("[parameters: %r]" % params_repr)
#     483 code_str = self._code_str()
#     484 if code_str:
#
# File e:\Programowanie\Anaconda\envs\marcinbereznicki\lib\site-packages\sqlalchemy\sql\util.py:522, in _repr_params.__repr__(self)
#     520 def __repr__(self):
#     521     if self.ismulti is None:
# --> 522         return self.trunc(self.params)
#     524     if isinstance(self.params, list):
#     525         typ = self._LIST
#
# File e:\Programowanie\Anaconda\envs\marcinbereznicki\lib\site-packages\sqlalchemy\sql\util.py:472, in _repr_base.trunc(self, value)
#     471 def trunc(self, value):
# --> 472     rep = repr(value)
#     473     lenrep = len(rep)
#     474     if lenrep > self.max_chars:
#
# MemoryError:
